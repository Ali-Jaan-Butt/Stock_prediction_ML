# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('stock_dataset.csv')

# %%
df.head()
# Out:
#   Ticker                          Company              Sector  \
# 0      A        Agilent Technologies Inc.          Healthcare
# 1     AA                       Alcoa Corp     Basic Materials
# 2    AAA  AXS First Priority CLO Bond ETF           Financial
# 3   AAAU  Goldman Sachs Physical Gold ETF           Financial
# 4   AACG        ATA Creativity Global ADR  Consumer Defensive
#
#                         Industry Country Market Cap    P/E   Price  \
# 0         Diagnostics & Research     USA     40.74B  33.11  139.03
# 1                       Aluminum     USA      6.07B      -   34.00
# 2           Exchange Traded Fund     USA          -      -   24.96
# 3           Exchange Traded Fund     USA          -      -   20.43
# 4  Education & Training Services   China     36.39M      -    1.16
#
#   Change in %     Volume
# 0       -0.53  1,014,199
# 1       -1.59  3,236,316
# 2       -0.18      6,303
# 3       -0.17  1,676,511
# 4        1.73     33,645

# %%
df.tail()
# Out:
#      Ticker                                            Company       Sector  \
# 9475   ZVSA                           ZyVersa Therapeutics Inc   Healthcare
# 9476    ZWS                    Zurn Elkay Water Solutions Corp  Industrials
# 9477   ZYME                                   Zymeworks BC Inc   Healthcare
# 9478   ZYXI                                          Zynex Inc   Healthcare
# 9479    ZZZ  CYBER HORNET S&P 500 and Bitcoin 75/25 Strateg...    Financial
#
#                             Industry Country Market Cap    P/E  Price  \
# 9475                   Biotechnology     USA      1.48M      -   0.90
# 9476  Pollution & Treatment Controls     USA      5.08B  47.74  29.41
# 9477                   Biotechnology     USA    734.05M   3.34  10.39
# 9478            Medical Distribution     USA    369.17M  25.43  10.89
# 9479            Exchange Traded Fund     USA          -      -  20.87
#
#      Change in %   Volume
# 9475       -5.16  272,792
# 9476       -0.88  753,995
# 9477       -2.90  300,983
# 9478        0.00  417,857
# 9479           -    7,387

# %%
df.sample(10)
# Out:
#      Ticker                                         Company  \
# 8683   USCI              United States Commodity Index Fund
# 4492   IPKW  Invesco International BuyBack Achievers TM ETF
# 1565   CHGG                                       Chegg Inc
# 1227   BSTZ     BlackRock Science and Technology Term Trust
# 9260   XELB                                 Xcel Brands Inc
# 9314   XMVM      Invesco S&P MidCap Value with Momentum ETF
# 8625   UMAY    Innovator U.S. Equity Ultra Buffer ETF - May
# 7423   SCHE              Schwab Emerging Markets Equity ETF
# 986    BITQ          Bitwise Crypto Industry Innovators ETF
# 574    ASNS                            Actelis Networks Inc
#
#                   Sector                       Industry Country Market Cap  \
# 8683           Financial           Exchange Traded Fund     USA          -
# 4492           Financial           Exchange Traded Fund     USA          -
# 1565  Consumer Defensive  Education & Training Services     USA      1.32B
# 1227           Financial       Closed-End Fund - Equity     USA      1.29B
# 9260   Consumer Cyclical          Apparel Manufacturing     USA     25.54M
# 9314           Financial           Exchange Traded Fund     USA          -
# 8625           Financial           Exchange Traded Fund     USA          -
# 7423           Financial           Exchange Traded Fund     USA          -
# 986            Financial           Exchange Traded Fund     USA          -
# 574           Technology        Communication Equipment     USA      3.01M
#
#         P/E  Price Change in %     Volume
# 8683      -  56.28       -1.23      6,358
# 4492      -  37.42        0.29        884
# 1565      -  11.36       -0.44  1,671,389
# 1227  23.54  16.71       -1.24    716,439
# 9260      -   1.29       -0.15     37,171
# 9314      -  50.34       -0.69     15,324
# 8625      -  29.41        0.03     10,397
# 7423      -  24.79        0.36  1,626,480
# 986       -  11.59      -10.91    582,738
# 574       -   1.12       -1.75     57,092

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9480 entries, 0 to 9479
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ticker       9479 non-null   object
#  1   Company      9480 non-null   object
#  2   Sector       9480 non-null   object
#  3   Industry     9480 non-null   object
#  4   Country      9480 non-null   object
#  5   Market Cap   9480 non-null   object
#  6   P/E          9480 non-null   object
#  7   Price        9480 non-null   object
#  8   Change in %  9480 non-null   object
#  9   Volume       9480 non-null   object
# dtypes: object(10)
# memory usage: 740.8+ KB

# %%
df['Volume'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df['Volume'].astype(int)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '1,014,199'
